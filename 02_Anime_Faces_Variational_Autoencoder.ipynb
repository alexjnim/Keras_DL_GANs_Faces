# %%
import numpy as np
import pandas as pd
import cv2 as cv
import os
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import gc
import requests

from collections import Counter

from PIL import Image
from io import BytesIO

warnings.filterwarnings('ignore')

# %%
import tensorflow as tf
from tensorflow import keras

import os
from classes.VAE import VariationalAutoencoder

import matplotlib.pyplot as plt
from matplotlib import cm
# %matplotlib inline


from keras.utils import to_categorical
from keras.preprocessing import image as keras_image
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.preprocessing.image import ImageDataGenerator

from keras import backend as K

from keras.models import Sequential, load_model, Model
from keras.layers import Input, BatchNormalization
from keras.layers import Dense, LSTM, GlobalAveragePooling1D, GlobalAveragePooling2D
from keras.layers import Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, Flatten, Dense, Conv2DTranspose, Reshape, Lambda, Activation, LeakyReLU, Dropout
from keras.models import Model
from keras import backend as K
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from keras.utils import plot_model
from keras.layers.advanced_activations import PReLU, LeakyReLU
from keras.layers import Conv2D, MaxPooling2D, GlobalMaxPooling2D

from keras.applications.inception_v3 import InceptionV3, preprocess_input
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### loading data

# %%
import cv2

def list_images(basePath, contains=None):
    # return the set of files that are valid
    return list_files(basePath, validExts=(".jpg", ".jpeg", ".png", ".bmp"), contains=contains)

def list_files(basePath, validExts=(".jpg", ".jpeg", ".png", ".bmp"), contains=None):
    # loop over the directory structure
    for (rootDir, dirNames, filenames) in os.walk(basePath):
        # loop over the filenames in the current directory
        for filename in filenames:
            # if the contains string is not none and the filename does not contain
            # the supplied string, then ignore the file
            if contains is not None and filename.find(contains) == -1:
                continue

            # determine the file extension of the current file
            ext = filename[filename.rfind("."):].lower()

            # check to see if the file is an image and should be processed
            if ext.endswith(validExts):
                # construct the path to the image and yield it
                imagePath = os.path.join(rootDir, filename).replace(" ", "\\ ")
                yield imagePath
                             
def load_images(directory='', size=(64,64)):
    images = []
    labels = []  # Integers corresponding to the categories in alphabetical order
    label = 0
    
    imagePaths = list(list_images(directory))
    
    for path in imagePaths:
        
        if not('OSX' in path):
        
            path = path.replace('\\','/')

            image = cv2.imread(path) #Reading the image with OpenCV
            image = cv2.resize(image,size) #Resizing the image, in case some are not of the same size

            images.append(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    
    return images

# %%
images=load_images('data')

# %% [markdown]
# ### reshaping images, making train val test sets and plotting example images

# %%
# Convert list with images to numpy array and reshape it 
X = np.array(images).reshape(-1, 64, 64, 3)

# Scaling data in array
X = X / 255.0

from sklearn.model_selection import train_test_split

# Splitting data to train and test datasets
X_train, X_test = train_test_split(X, test_size = 0.2, shuffle = True, random_state = 66)

# %%
n = int(len(X_test)/2)
X_valid = X_test[:n]
X_test = X_test[n:]

# %%
n_to_show = 10
example_idx = np.random.choice(range(len(X)), n_to_show)
example_images = X[example_idx]


fig = plt.figure(figsize=(15, 3))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(n_to_show):
    img = example_images[i].squeeze()
    ax = fig.add_subplot(2, n_to_show, i+1)
    ax.axis('off')
    ax.imshow(img)

# %% [markdown]
# ### building the Variational Autoencoder

# %%
VAE = VariationalAutoencoder(
    input_dim = (64,64,3)
    , encoder_conv_filters = [32,64,64,64]
    , encoder_conv_kernel_size = [3,3,3,3]
    , encoder_conv_strides = [2,2,2,2]
    , decoder_conv_t_filters = [64,64,32,3]
    , decoder_conv_t_kernel_size = [3,3,3,3]
    ### 3 for the last decoder layer as we as we want RGB images
    , decoder_conv_t_strides = [2,2,2,2]
    , z_dim = 200
    , use_batch_norm=True
    , use_dropout=True)

VAE._build()

# %%
keras.utils.plot_model(VAE.encoder, "figures/Var_autoencoder_encoder_model.png", show_shapes=True)

# %%
keras.utils.plot_model(VAE.decoder, "figures/Var_autoencoder_decoder_model.png", show_shapes=True)

# %%
keras.utils.plot_model(VAE.model, "figures/Var_autoencoder_model.png", show_shapes=True)

# %%
LEARNING_RATE = 0.0005
R_LOSS_FACTOR = 1000

VAE.compile(LEARNING_RATE, R_LOSS_FACTOR)

# %%
#optimizer = Adam(lr=LEARNING_RATE)

#def r_loss(y_true, y_pred):
 #   return K.mean(K.square(y_true - y_pred), axis = [1,2,3])

#VAE.model.compile(optimizer=optimizer, loss = r_loss, metrics = ['accuracy'])

# %%
checkpointer = ModelCheckpoint(filepath='saved_models/var_autoencoder.h5',
                               verbose=2, save_best_only=True)

early_stopping_cb = EarlyStopping(patience=3, restore_best_weights=True)

# %%
### note that we are testing with X_train against X_train - we want the autoencoder to be able to reproduce X_train

history = VAE.model.fit(X_train, X_train,
                    epochs=30, batch_size=32, verbose=2,
                    validation_data=(X_valid, X_valid),
                    callbacks=[checkpointer, early_stopping_cb])
# Out:
# Train on 17240 samples, validate on 2155 samples
# Epoch 1/30
#  - 130s - loss: 93.3185 - vae_r_loss: 62.5056 - vae_kl_loss: 30.8129 - accuracy: 0.6235 - val_loss: 57.7716 - val_vae_r_loss: 51.8352 - val_vae_kl_loss: 5.9364 - val_accuracy: 0.7419
#
# Epoch 00001: val_loss improved from inf to 57.77163, saving model to saved_models/var_autoencoder.h5
# Epoch 2/30
#  - 140s - loss: 61.6209 - vae_r_loss: 51.8376 - vae_kl_loss: 9.7833 - accuracy: 0.7216 - val_loss: 53.8124 - val_vae_r_loss: 48.4833 - val_vae_kl_loss: 5.3291 - val_accuracy: 0.7424
#
# Epoch 00002: val_loss improved from 57.77163 to 53.81241, saving model to saved_models/var_autoencoder.h5
# Epoch 3/30
#  - 139s - loss: 56.0247 - vae_r_loss: 49.2177 - vae_kl_loss: 6.8070 - accuracy: 0.7336 - val_loss: 51.7516 - val_vae_r_loss: 46.6528 - val_vae_kl_loss: 5.0989 - val_accuracy: 0.7426
#
# Epoch 00003: val_loss improved from 53.81241 to 51.75162, saving model to saved_models/var_autoencoder.h5
# Epoch 4/30
#  - 145s - loss: 53.8774 - vae_r_loss: 48.0130 - vae_kl_loss: 5.8643 - accuracy: 0.7379 - val_loss: 51.3328 - val_vae_r_loss: 46.2093 - val_vae_kl_loss: 5.1235 - val_accuracy: 0.7437
#
# Epoch 00004: val_loss improved from 51.75162 to 51.33285, saving model to saved_models/var_autoencoder.h5
# Epoch 5/30
#  - 129s - loss: 52.9672 - vae_r_loss: 47.4304 - vae_kl_loss: 5.5368 - accuracy: 0.7383 - val_loss: 51.0204 - val_vae_r_loss: 46.1357 - val_vae_kl_loss: 4.8847 - val_accuracy: 0.7456
#
# Epoch 00005: val_loss improved from 51.33285 to 51.02042, saving model to saved_models/var_autoencoder.h5
# Epoch 6/30
#  - 137s - loss: 52.4510 - vae_r_loss: 47.0332 - vae_kl_loss: 5.4178 - accuracy: 0.7391 - val_loss: 50.6940 - val_vae_r_loss: 45.3242 - val_vae_kl_loss: 5.3697 - val_accuracy: 0.7445
#
# Epoch 00006: val_loss improved from 51.02042 to 50.69397, saving model to saved_models/var_autoencoder.h5
# Epoch 7/30
#  - 139s - loss: 52.1385 - vae_r_loss: 46.7258 - vae_kl_loss: 5.4127 - accuracy: 0.7399 - val_loss: 50.4893 - val_vae_r_loss: 45.4586 - val_vae_kl_loss: 5.0307 - val_accuracy: 0.7456
#
# Epoch 00007: val_loss improved from 50.69397 to 50.48932, saving model to saved_models/var_autoencoder.h5
# Epoch 8/30
#  - 144s - loss: 51.7800 - vae_r_loss: 46.1894 - vae_kl_loss: 5.5906 - accuracy: 0.7441 - val_loss: 50.0498 - val_vae_r_loss: 44.4677 - val_vae_kl_loss: 5.5822 - val_accuracy: 0.7577
#
# Epoch 00008: val_loss improved from 50.48932 to 50.04983, saving model to saved_models/var_autoencoder.h5
# Epoch 9/30
#  - 140s - loss: 51.4216 - vae_r_loss: 45.5814 - vae_kl_loss: 5.8402 - accuracy: 0.7517 - val_loss: 49.7501 - val_vae_r_loss: 44.1697 - val_vae_kl_loss: 5.5805 - val_accuracy: 0.7675
#
# Epoch 00009: val_loss improved from 50.04983 to 49.75015, saving model to saved_models/var_autoencoder.h5
# Epoch 10/30
#  - 140s - loss: 50.9969 - vae_r_loss: 45.0191 - vae_kl_loss: 5.9778 - accuracy: 0.7548 - val_loss: 49.2785 - val_vae_r_loss: 43.2431 - val_vae_kl_loss: 6.0354 - val_accuracy: 0.7708
#
# Epoch 00010: val_loss improved from 49.75015 to 49.27846, saving model to saved_models/var_autoencoder.h5
# Epoch 11/30
#  - 139s - loss: 50.7829 - vae_r_loss: 44.6678 - vae_kl_loss: 6.1151 - accuracy: 0.7573 - val_loss: 49.1419 - val_vae_r_loss: 42.9941 - val_vae_kl_loss: 6.1479 - val_accuracy: 0.7705
#
# Epoch 00011: val_loss improved from 49.27846 to 49.14195, saving model to saved_models/var_autoencoder.h5
# Epoch 12/30
#  - 147s - loss: 50.5029 - vae_r_loss: 44.3078 - vae_kl_loss: 6.1950 - accuracy: 0.7594 - val_loss: 49.1237 - val_vae_r_loss: 42.6852 - val_vae_kl_loss: 6.4386 - val_accuracy: 0.7753
#
# Epoch 00012: val_loss improved from 49.14195 to 49.12373, saving model to saved_models/var_autoencoder.h5
# Epoch 13/30
#  - 136s - loss: 50.2463 - vae_r_loss: 43.9432 - vae_kl_loss: 6.3032 - accuracy: 0.7626 - val_loss: 48.7412 - val_vae_r_loss: 42.6118 - val_vae_kl_loss: 6.1293 - val_accuracy: 0.7765
#
# Epoch 00013: val_loss improved from 49.12373 to 48.74116, saving model to saved_models/var_autoencoder.h5
# Epoch 14/30
#  - 145s - loss: 50.0881 - vae_r_loss: 43.7583 - vae_kl_loss: 6.3298 - accuracy: 0.7662 - val_loss: 48.7048 - val_vae_r_loss: 42.5625 - val_vae_kl_loss: 6.1423 - val_accuracy: 0.7807
#
# Epoch 00014: val_loss improved from 48.74116 to 48.70484, saving model to saved_models/var_autoencoder.h5
# Epoch 15/30
#  - 145s - loss: 49.9476 - vae_r_loss: 43.5610 - vae_kl_loss: 6.3866 - accuracy: 0.7686 - val_loss: 48.4782 - val_vae_r_loss: 42.0160 - val_vae_kl_loss: 6.4622 - val_accuracy: 0.7837
#
# Epoch 00015: val_loss improved from 48.70484 to 48.47815, saving model to saved_models/var_autoencoder.h5
# Epoch 16/30
#  - 140s - loss: 49.9218 - vae_r_loss: 43.5077 - vae_kl_loss: 6.4141 - accuracy: 0.7709 - val_loss: 48.3942 - val_vae_r_loss: 41.7764 - val_vae_kl_loss: 6.6178 - val_accuracy: 0.7847
#
# Epoch 00016: val_loss improved from 48.47815 to 48.39421, saving model to saved_models/var_autoencoder.h5
# Epoch 17/30
#  - 141s - loss: 49.7942 - vae_r_loss: 43.3746 - vae_kl_loss: 6.4196 - accuracy: 0.7719 - val_loss: 48.4551 - val_vae_r_loss: 41.8953 - val_vae_kl_loss: 6.5598 - val_accuracy: 0.7832
#
# Epoch 00017: val_loss did not improve from 48.39421
# Epoch 18/30
#  - 143s - loss: 49.7647 - vae_r_loss: 43.3462 - vae_kl_loss: 6.4185 - accuracy: 0.7739 - val_loss: 48.2797 - val_vae_r_loss: 41.8903 - val_vae_kl_loss: 6.3894 - val_accuracy: 0.7863
#
# Epoch 00018: val_loss improved from 48.39421 to 48.27969, saving model to saved_models/var_autoencoder.h5
# Epoch 19/30
#  - 146s - loss: 49.6929 - vae_r_loss: 43.2502 - vae_kl_loss: 6.4427 - accuracy: 0.7729 - val_loss: 48.5200 - val_vae_r_loss: 41.9057 - val_vae_kl_loss: 6.6143 - val_accuracy: 0.7893
#
# Epoch 00019: val_loss did not improve from 48.27969
# Epoch 20/30
#  - 146s - loss: 49.7348 - vae_r_loss: 43.2610 - vae_kl_loss: 6.4738 - accuracy: 0.7748 - val_loss: 48.1351 - val_vae_r_loss: 41.5724 - val_vae_kl_loss: 6.5627 - val_accuracy: 0.7874
#
# Epoch 00020: val_loss improved from 48.27969 to 48.13511, saving model to saved_models/var_autoencoder.h5
# Epoch 21/30
#  - 126s - loss: 49.5520 - vae_r_loss: 43.0894 - vae_kl_loss: 6.4627 - accuracy: 0.7754 - val_loss: 48.2212 - val_vae_r_loss: 41.9646 - val_vae_kl_loss: 6.2567 - val_accuracy: 0.7918
#
# Epoch 00021: val_loss did not improve from 48.13511
# Epoch 22/30
#  - 96s - loss: 49.5340 - vae_r_loss: 43.0161 - vae_kl_loss: 6.5178 - accuracy: 0.7741 - val_loss: 48.4781 - val_vae_r_loss: 42.2243 - val_vae_kl_loss: 6.2538 - val_accuracy: 0.7858
#
# Epoch 00022: val_loss did not improve from 48.13511
# Epoch 23/30
#  - 60s - loss: 49.5750 - vae_r_loss: 43.0110 - vae_kl_loss: 6.5640 - accuracy: 0.7759 - val_loss: 48.0901 - val_vae_r_loss: 41.6034 - val_vae_kl_loss: 6.4867 - val_accuracy: 0.7876
#
# Epoch 00023: val_loss improved from 48.13511 to 48.09008, saving model to saved_models/var_autoencoder.h5
# Epoch 24/30
#  - 64s - loss: 49.4562 - vae_r_loss: 42.9267 - vae_kl_loss: 6.5295 - accuracy: 0.7752 - val_loss: 48.2511 - val_vae_r_loss: 41.6805 - val_vae_kl_loss: 6.5706 - val_accuracy: 0.7905
#
# Epoch 00024: val_loss did not improve from 48.09008
# Epoch 25/30
#  - 62s - loss: 49.4948 - vae_r_loss: 42.9173 - vae_kl_loss: 6.5776 - accuracy: 0.7761 - val_loss: 48.1383 - val_vae_r_loss: 41.8772 - val_vae_kl_loss: 6.2611 - val_accuracy: 0.7899
#
# Epoch 00025: val_loss did not improve from 48.09008
# Epoch 26/30
#  - 61s - loss: 49.4637 - vae_r_loss: 42.9029 - vae_kl_loss: 6.5608 - accuracy: 0.7758 - val_loss: 48.0923 - val_vae_r_loss: 41.2447 - val_vae_kl_loss: 6.8476 - val_accuracy: 0.7924
#
# Epoch 00026: val_loss did not improve from 48.09008

# %% [markdown]
# ### training history plots

# %%
list(history.history.keys())
# Out:
# ['val_loss',
#  'val_vae_r_loss',
#  'val_vae_kl_loss',
#  'val_accuracy',
#  'loss',
#  'vae_r_loss',
#  'vae_kl_loss',
#  'accuracy']

# %%
def history_plot(history, n):

    tot_pairs = np.int(len(list(history.history.keys()))/2)

    plt.figure(figsize=(18,12))

    for i in range(tot_pairs):

        plt.subplot(np.int(tot_pairs)*100+11+np.int(i))
        plt.plot(history.history[list(history.history.keys())[i]][n:],
                                     color='#4876ff', label = list(history.history.keys())[i])
        plt.plot(history.history[list(history.history.keys())[i + tot_pairs]][n:],
                                     color='slategray', label = list(history.history.keys())[i + tot_pairs])
        plt.xlabel("Epochs")
        plt.ylabel(list(history.history.keys())[i+tot_pairs])
        plt.legend()
        plt.grid()
        plt.title(list(history.history.keys())[i+tot_pairs])

    plt.show()

# %%
history_plot(history, 0)

# %% [markdown]
# ### load model from training the variational neural net

# %%
model = keras.models.load_model("save/var_autoencoder.h5")

# %% [markdown]
# ### evaluating on test set

# %%
score = VAE.model.evaluate(X_test, X_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[3])
# Out:
# Test loss: 47.532808158747116
# Test accuracy: 0.7969996929168701

# %% [markdown]
# ### analysis of variational autoencoder

# %%
n_to_show = 10
example_idx = np.random.choice(range(len(X)), n_to_show)
example_images = X[example_idx]
#example_images = X[np.array([230, 7809])]

z_points = VAE.encoder.predict(example_images)

reconst_images = VAE.decoder.predict(z_points)

fig = plt.figure(figsize=(15, 3))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(n_to_show):
    img = example_images[i]#.squeeze()
    ax = fig.add_subplot(2, n_to_show, i+1)
    ax.axis('off')
    #ax.text(0.5, -0.35, str(np.round(z_points[i],1)), fontsize=10, ha='center', transform=ax.transAxes)
    ax.imshow(img)

for i in range(n_to_show):
    img = reconst_images[i]#.squeeze()
    ax = fig.add_subplot(2, n_to_show, i+n_to_show+1)
    ax.axis('off')
    ax.imshow(img)
    
plt.savefig('model_images/VAE_encoder_decoder_images.png')

# %% [markdown]
# ### newly generated points

# %%
n_to_show = 30

znew = np.random.normal(size = (n_to_show, VAE.z_dim))

reconst = VAE.decoder.predict(np.array(znew))

fig = plt.figure(figsize=(18, 5))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(n_to_show):
    ax = fig.add_subplot(3, 10, i+1)
    ax.imshow(reconst[i, :,:,:])
    ax.axis('off')

plt.savefig('model_images/VAE_new_images.png')    
    
plt.show()
